# %% [markdown]
# <a href="https://colab.research.google.com/github/rgodoy62/cpython/blob/main/Eventos_naturais_NOAA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importando biblioteca
import pandas as pd
import matplotlib.pyplot as plt

# %%
# determinando os dataframes
df_1990s_terremotos = pd.read_csv("/content/drive/MyDrive/datasets/1990-1999_earthquakes.csv")
df_2000s_terremotos = pd.read_csv("/content/drive/MyDrive/datasets/2000-2021_earthquakes.csv")
df_1990s_tsunamis = pd.read_csv("/content/drive/MyDrive/datasets/1990-1999_tsunamis.csv")
df_2000s_tsunamis = pd.read_csv("/content/drive/MyDrive/datasets/2000-2021_tsunamis.csv")
df_1990s_vulcoes = pd.read_csv("/content/drive/MyDrive/datasets/1990-1999_volcanoes.csv")
df_2000s_vulcoes = pd.read_csv("/content/drive/MyDrive/datasets/2000-2021_volcanoes.csv")

# %%
# mostrando os 5 primeiros eventos sobre terremotos da planilha selecionada
df_1990s_terremotos.head()
# Out:
#    Year   Mo  ...  Total Houses Damaged  Total Houses Damaged Description
# 0  1900  1.0  ...                   NaN                               NaN
# 1  1900  1.0  ...                   NaN                               NaN
# 2  1900  1.0  ...                   NaN                               3.0
# 3  1900  1.0  ...                   NaN                               NaN
# 4  1900  5.0  ...                   NaN                               NaN
#
# [5 rows x 38 columns]

# %%
# mostrando os 5 primeiros eventos sobre tsunami da planilha selecionada
df_1990s_tsunamis.head()
# Out:
#    Year    Mo  ...  Total Houses Damaged  Total Houses Damaged Description
# 0  1900   1.0  ...                   NaN                               NaN
# 1  1900   8.0  ...                   NaN                               NaN
# 2  1900   9.0  ...                   NaN                               1.0
# 3  1900   9.0  ...                   NaN                               NaN
# 4  1900  10.0  ...                   NaN                               NaN
#
# [5 rows x 45 columns]

# %%
# mostrando os 5 primeiros eventos sobre atividades vulcanicas da planilha selecionada
df_1990s_vulcoes.head()
# Out:
#    Year   Mo  ...  Total Houses Destroyed  Total Houses Destroyed Description
# 0  1900  1.0  ...                     NaN                                 NaN
# 1  1900  2.0  ...                     NaN                                 NaN
# 2  1900  7.0  ...                     NaN                                 NaN
# 3  1900  NaN  ...                     NaN                                 NaN
# 4  1901  5.0  ...                     NaN                                 NaN
#
# [5 rows x 34 columns]

# %%
# mostrando os 5 primeiros eventos sobre terremotos da planilha selecionada
df_2000s_terremotos.head()
# Out:
#    Year  Mo  ...  Total Houses Damaged  Total Houses Damaged Description
# 0  2000   1  ...                 100.0                               2.0
# 1  2000   1  ...                8800.0                               4.0
# 2  2000   1  ...                   NaN                               NaN
# 3  2000   2  ...                 300.0                               3.0
# 4  2000   2  ...                   NaN                               NaN
#
# [5 rows x 38 columns]

# %%
# mostrando os 5 primeiros eventos sobre tsunamis da planilha selecionada
df_2000s_tsunamis.head()
# Out:
#    Year   Mo  ...  Total Houses Damaged  Total Houses Damaged Description
# 0  2000  1.0  ...                   NaN                               NaN
# 1  2000  4.0  ...                   NaN                               NaN
# 2  2000  5.0  ...                   NaN                               NaN
# 3  2000  6.0  ...                   NaN                               NaN
# 4  2000  7.0  ...                   NaN                               NaN
#
# [5 rows x 45 columns]

# %%
# mostrando os 5 primeiros eventos sobre atividades vulcanicas da planilha selecionada
df_2000s_vulcoes.head()
# Out:
#    Year    Mo  ...  Total Houses Destroyed  Total Houses Destroyed Description
# 0  2000   6.0  ...                     NaN                                 NaN
# 1  2000   7.0  ...                     NaN                                 NaN
# 2  2000   8.0  ...                     NaN                                 NaN
# 3  2000  11.0  ...                     NaN                                 NaN
# 4  2000  11.0  ...                     NaN                                 NaN
#
# [5 rows x 34 columns]

# %%
# mostrando o número de linhas e colunas da planilha selecionada
df_2000s_vulcoes.shape
# Out:
# (126, 34)

# %%
# mostrando o nome de cada coluna da planilha selecionada
df_2000s_vulcoes.columns
# Out:
# Index(['Year', 'Mo', 'Dy', 'Tsu', 'Eq', 'Name', 'Location', 'Country',
#        'Latitude', 'Longitude', 'Elevation (m)', 'Type', 'VEI', 'Agent',
#        'Deaths', 'Death Description', 'Missing', 'Missing Description',
#        'Injuries', 'Injuries Description', 'Damage ($Mil)',
#        'Damage Description', 'Houses Destroyed',
#        'Houses Destroyed Description', 'Total Deaths',
#        'Total Death Description', 'Total Missing', 'Total Missing Description',
#        'Total Injuries', 'Total Injuries Description', 'Total Damage ($Mil)',
#        'Total Damage Description', 'Total Houses Destroyed',
#        'Total Houses Destroyed Description'],
#       dtype='object')

# %%
# mostrando o nome de cada coluna da planilha selecionada
df_2000s_tsunamis.columns
# Out:
# Index(['Year', 'Mo', 'Dy', 'Hr', 'Mn', 'Sec', 'Tsunami Event Validity',
#        'Tsunami Cause Code', 'Earthquake Magnitude', 'Vol', 'More Info',
#        'Deposits', 'Country', 'Location Name', 'Latitude', 'Longitude',
#        'Maximum Water Height (m)', 'Number of Runups',
#        'Tsunami Magnitude (Abe)', 'Tsunami Magnitude (Iida)',
#        'Tsunami Intensity', 'Deaths', 'Death Description', 'Missing',
#        'Missing Description', 'Injuries', 'Injuries Description',
#        'Damage ($Mil)', 'Damage Description', 'Houses Destroyed',
#        'Houses Destroyed Description', 'Houses Damaged',
#        'Houses Damaged Description', 'Total Deaths', 'Total Death Description',
#        'Total Missing', 'Total Missing Description', 'Total Injuries',
#        'Total Injuries Description', 'Total Damage ($Mil)',
#        'Total Damage Description', 'Total Houses Destroyed',
#        'Total Houses Destroyed Description', 'Total Houses Damaged',
# ...

# %%
# mostrando o nome de cada coluna da planilha selecionada
df_2000s_terremotos.columns
# Out:
# Index(['Year', 'Mo', 'Dy', 'Hr', 'Mn', 'Sec', 'Tsu', 'Vol', 'Location Name',
#        'Latitude', 'Longitude', 'Focal Depth (km)', 'Mag', 'MMI Int', 'Deaths',
#        'Death Description', 'Missing', 'Missing Description', 'Injuries',
#        'Injuries Description', 'Damage ($Mil)', 'Damage Description',
#        'Houses Destroyed', 'Houses Destroyed Description', 'Houses Damaged',
#        'Houses Damaged Description', 'Total Deaths', 'Total Death Description',
#        'Total Missing', 'Total Missing Description', 'Total Injuries',
#        'Total Injuries Description', 'Total Damage ($Mil)',
#        'Total Damage Description', 'Total Houses Destroyed',
#        'Total Houses Destroyed Description', 'Total Houses Damaged',
#        'Total Houses Damaged Description'],
#       dtype='object')

# %%
# mostrando os tipos de dados para cada coluna da planilha selecionada
df_2000s_terremotos.dtypes
# Out:
# Year                                    int64
# Mo                                      int64
# Dy                                      int64
# Hr                                    float64
# Mn                                    float64
# Sec                                   float64
# Tsu                                   float64
# Vol                                   float64
# Location Name                          object
# Latitude                              float64
# Longitude                             float64
# Focal Depth (km)                      float64
# Mag                                   float64
# MMI Int                               float64
# Deaths                                float64
# Death Description                     float64
# Missing                               float64
# Missing Description                   float64
# Injuries                              float64
# Injuries Description                  float64
# ...

# %%
# mostrando os tipos de dados para cada coluna da planilha selecionada
df_2000s_tsunamis.dtypes
# Out:
# Year                                    int64
# Mo                                    float64
# Dy                                    float64
# Hr                                    float64
# Mn                                    float64
# Sec                                   float64
# Tsunami Event Validity                  int64
# Tsunami Cause Code                      int64
# Earthquake Magnitude                  float64
# Vol                                   float64
# More Info                             float64
# Deposits                                int64
# Country                                object
# Location Name                          object
# Latitude                              float64
# Longitude                             float64
# Maximum Water Height (m)              float64
# Number of Runups                        int64
# Tsunami Magnitude (Abe)               float64
# Tsunami Magnitude (Iida)              float64
# ...

# %%
# mostrando os tipos de dados para cada coluna da planilha selecionada
df_2000s_vulcoes.dtypes
# Out:
# Year                                    int64
# Mo                                    float64
# Dy                                    float64
# Tsu                                   float64
# Eq                                    float64
# Name                                   object
# Location                               object
# Country                                object
# Latitude                              float64
# Longitude                             float64
# Elevation (m)                           int64
# Type                                   object
# VEI                                   float64
# Agent                                  object
# Deaths                                float64
# Death Description                     float64
# Missing                               float64
# Missing Description                   float64
# Injuries                              float64
# Injuries Description                  float64
# ...

# %%
# mostrando os 5 últimos eventos referente as atividades vulcânicas da planilha selecionada
df_2000s_vulcoes.tail()
# Out:
#      Year   Mo  ...  Total Houses Destroyed  Total Houses Destroyed Description
# 121  2021  3.0  ...                     NaN                                 NaN
# 122  2021  3.0  ...                     NaN                                 NaN
# 123  2021  4.0  ...                     NaN                                 NaN
# 124  2021  5.0  ...                  5000.0                                 4.0
# 125  2021  9.0  ...                   855.0                                 3.0
#
# [5 rows x 34 columns]

# %%
# mostrando os 5 últimos eventos referente aos tsunamis da planilha selecionada
df_2000s_tsunamis.tail()
# Out:
#      Year    Mo  ...  Total Houses Damaged  Total Houses Damaged Description
# 300  2021   8.0  ...                   NaN                               NaN
# 301  2021   8.0  ...                   NaN                               NaN
# 302  2021   8.0  ...               83770.0                               4.0
# 303  2021   9.0  ...                7317.0                               4.0
# 304  2021  10.0  ...                   NaN                               1.0
#
# [5 rows x 45 columns]

# %%
# mostrando os 5 últimos eventos referente aos terremotos da planilha selecionada
df_2000s_terremotos.tail()
# Out:
#       Year  Mo  ...  Total Houses Damaged  Total Houses Damaged Description
# 1237  2021   9  ...                  46.0                               1.0
# 1238  2021   9  ...                   NaN                               NaN
# 1239  2021  10  ...                   NaN                               2.0
# 1240  2021  10  ...                   NaN                               1.0
# 1241  2021  10  ...                 524.0                               3.0
#
# [5 rows x 38 columns]

# %%
# mostrando os 20 últimos eventos referente aos terremotos da planilha selecionada
df_1990s_terremotos.tail(20)
# Out:
#       Year    Mo  ...  Total Houses Damaged  Total Houses Damaged Description
# 2528  1999   8.0  ...                   NaN                               NaN
# 2529  1999   9.0  ...                   NaN                               NaN
# 2530  1999   9.0  ...                   NaN                               NaN
# 2531  1999   9.0  ...               82000.0                               4.0
# 2532  1999   9.0  ...                   NaN                               NaN
# 2533  1999   9.0  ...                2000.0                               4.0
# 2534  1999  10.0  ...                   NaN                               NaN
# 2535  1999  10.0  ...                   NaN                               NaN
# 2536  1999  10.0  ...                1100.0                               4.0
# 2537  1999  11.0  ...                   NaN                               NaN
# 2538  1999  11.0  ...                   NaN                               NaN
# ...

# %%
# mostrando os 20 primeiros eventos referente aos terremotos da planilha selecionada
df_1990s_terremotos.head(20)
# Out:
#     Year    Mo  ...  Total Houses Damaged  Total Houses Damaged Description
# 0   1900   1.0  ...                   NaN                               NaN
# 1   1900   1.0  ...                   NaN                               NaN
# 2   1900   1.0  ...                   NaN                               3.0
# 3   1900   1.0  ...                   NaN                               NaN
# 4   1900   5.0  ...                   NaN                               NaN
# 5   1900   6.0  ...                   NaN                               NaN
# 6   1900   6.0  ...                   NaN                               NaN
# 7   1900   7.0  ...                   NaN                               NaN
# 8   1900   7.0  ...                   NaN                               NaN
# 9   1900   8.0  ...                   NaN                               NaN
# 10  1900   9.0  ...                   NaN                               1.0
# ...

# %%
# retornando informações que possivelmente servirão para estatísticas referente a planilha escolhida.
df_2000s_terremotos.describe()
# Out:
#               Year  ...  Total Houses Damaged Description
# count  1242.000000  ...                        586.000000
# mean   2010.252818  ...                          2.508532
# std       5.948382  ...                          1.157995
# min    2000.000000  ...                          1.000000
# 25%    2005.000000  ...                          1.000000
# 50%    2010.000000  ...                          3.000000
# 75%    2016.000000  ...                          4.000000
# max    2021.000000  ...                          4.000000
#
# [8 rows x 35 columns]

# %%
# retornando valores únicos da coluna ano => Year
df_1990s_terremotos["Year"].unique()
# Out:
# array([1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910,
#        1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921,
#        1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932,
#        1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943,
#        1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954,
#        1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965,
#        1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976,
#        1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
#        1999])

# %%
# retornando valores únicos da coluna nome da localização => Location name. Se observa que não foram apresentados todas colunas já que tem ...
df_1990s_terremotos["Location Name"].unique()
# Out:
# array(['INDONESIA:  GALELA (HALMAHERA ISLAND)', 'JAPAN:  SEA OF JAPAN',
#        'INDONESIA:  JAVA:  SUKABUMI', ...,
#        'PHILIPPINES:  S LUZON:  MANILA, SANTA CRUZ',
#        'INDONESIA:  PANDEGLANG, W JAWA, SE SUMATERA',
#        'ALGERIA:  NORTHERN:  AIN TEMOUCHENT'], dtype=object)

# %%
# Filtrando uma variavel chamada México para apresentar todos os eventos referido 
MEXICO = df_1990s_terremotos.loc[df_1990s_terremotos["Location Name"] == "MEXICO"]
# o número 2549 é o número total de linhas da referida planilha
MEXICO.head(2549)
# Out:
#    Year   Mo  ...  Total Houses Damaged  Total Houses Damaged Description
# 3  1900  1.0  ...                   NaN                               NaN
#
# [1 rows x 38 columns]

# %%
# Filtrando uma variavel chamada Mongólia para apresentar todos os eventos referido 
MONGOLIA = df_1990s_terremotos.loc[df_1990s_terremotos["Location Name"] == "MONGOLIA"]
MONGOLIA.head(2549)
# Out:
#       Year    Mo  ...  Total Houses Damaged  Total Houses Damaged Description
# 59    1903   2.0  ...                   NaN                               NaN
# 112   1905   7.0  ...                   NaN                               NaN
# 113   1905   7.0  ...                   NaN                               NaN
# 681   1930  11.0  ...                   NaN                               NaN
# 1262  1957  12.0  ...                   NaN                               NaN
# 1512  1967   1.0  ...                   NaN                               NaN
# 1735  1974   7.0  ...                   NaN                               NaN
#
# [7 rows x 38 columns]

# %%
# Filtrando uma variavel chamada ano de 1962 para apresentar todos os eventos referido ao mesmo na planilha selecionada
Ano_1962 = df_1990s_terremotos.loc[df_1990s_terremotos["Year"] == 1962] 
Ano_1962.head(2549)
# Out:
#       Year    Mo  ...  Total Houses Damaged  Total Houses Damaged Description
# 1371  1962   1.0  ...                   NaN                               NaN
# 1372  1962   1.0  ...                   NaN                               NaN
# 1373  1962   2.0  ...                   NaN                               NaN
# 1374  1962   2.0  ...                   NaN                               NaN
# 1375  1962   3.0  ...                   NaN                               NaN
# 1376  1962   3.0  ...                   NaN                               NaN
# 1377  1962   3.0  ...                   NaN                               NaN
# 1378  1962   4.0  ...                   NaN                               NaN
# 1379  1962   4.0  ...                   NaN                               NaN
# 1380  1962   4.0  ...                   NaN                               NaN
# 1381  1962   4.0  ...                   NaN                               NaN
# ...

# %%
# Filtrando uma variavel chamada ano de 1969 para apresentar todos os eventos referido ao mesmo na planilha selecionada
Ano_1969 = df_1990s_terremotos.loc[df_1990s_terremotos["Year"] == 1969] 
Ano_1969.head(2549)
# Out:
#       Year    Mo  ...  Total Houses Damaged  Total Houses Damaged Description
# 1577  1969   1.0  ...                   NaN                               NaN
# 1578  1969   1.0  ...                   NaN                               NaN
# 1579  1969   1.0  ...                   NaN                               NaN
# 1580  1969   1.0  ...                   NaN                               NaN
# 1581  1969   2.0  ...                   NaN                               NaN
# 1582  1969   2.0  ...                   NaN                               NaN
# 1583  1969   2.0  ...                   NaN                               4.0
# 1584  1969   3.0  ...                   NaN                               NaN
# 1585  1969   3.0  ...                   NaN                               NaN
# 1586  1969   3.0  ...                   NaN                               NaN
# 1587  1969   3.0  ...                   NaN                               NaN
# ...

# %%
# Filtrando uma variavel chamada ano de 1997 para apresentar todos os eventos referido ao mesmo na planilha selecionada
Ano_1997 = df_1990s_terremotos.loc[df_1990s_terremotos["Year"] == 1997] 
Ano_1997.head(2549)
# Out:
#       Year    Mo  ...  Total Houses Damaged  Total Houses Damaged Description
# 2448  1997   1.0  ...                   NaN                               NaN
# 2449  1997   1.0  ...                   NaN                               NaN
# 2450  1997   1.0  ...                   NaN                               NaN
# 2451  1997   1.0  ...                   NaN                               NaN
# 2452  1997   2.0  ...               11000.0                               4.0
# 2453  1997   2.0  ...                   NaN                               NaN
# 2454  1997   2.0  ...                   NaN                               NaN
# 2455  1997   3.0  ...                   NaN                               NaN
# 2456  1997   3.0  ...                   NaN                               1.0
# 2457  1997   3.0  ...                   NaN                               NaN
# 2458  1997   4.0  ...                   NaN                               NaN
# ...

# %%
# Filtrando uma variavel chamada ano de 2006 para apresentar todos os eventos referido ao mesmo na planilha selecionada * Não está atualizada porque o século não finalizou
Ano_2006 = df_2000s_terremotos.loc[df_2000s_terremotos["Year"] == 2006] 
# 1243
Ano_2006.head()
# Out:
#      Year  Mo  ...  Total Houses Damaged  Total Houses Damaged Description
# 333  2006   1  ...                   NaN                               NaN
# 334  2006   1  ...                   NaN                               NaN
# 335  2006   1  ...                   NaN                               NaN
# 336  2006   2  ...                   NaN                               NaN
# 337  2006   2  ...                   NaN                               NaN
#
# [5 rows x 38 columns]

# %%
Ano_1962["Year"].unique
# Out:
# <bound method Series.unique of 1371    1962
# 1372    1962
# 1373    1962
# 1374    1962
# 1375    1962
# 1376    1962
# 1377    1962
# 1378    1962
# 1379    1962
# 1380    1962
# 1381    1962
# 1382    1962
# 1383    1962
# 1384    1962
# 1385    1962
# 1386    1962
# 1387    1962
# 1388    1962
# 1389    1962
# 1390    1962
# 1391    1962
# 1392    1962
# 1393    1962
# 1394    1962
# 1395    1962
# 1396    1962
# 1397    1962
# 1398    1962
# 1399    1962
# 1400    1962
# 1401    1962
# 1402    1962
# 1403    1962
# 1404    1962
# Name: Year, dtype: int64>

# %%
# Realizando agrupamento de dados - quantos eventos por locais 
df_1990s_terremotos.groupby("Location Name")["Year"].nunique(2556)
# Out:
# Location Name
# AFGHANISTAN                                             2
# AFGHANISTAN-TAJIKISTAN:  YAR HUSAIN, ASTOR              1
# AFGHANISTAN:  BADAKHSHAN, TAKHAR                        1
# AFGHANISTAN:  BADAKHSTAN PROVINCE                       1
# AFGHANISTAN:  BADAKHSTAN, BAGHLAN, LAGHMAN, NAGARHAR    1
#                                                        ..
# WYOMING:  AFTON                                         1
# WYOMING:  DOUGLAS, MEDICINE BOW                         1
# YEMEN:  DHAMAR                                          1
# YEMEN:  RAZIH                                           1
# YEMEN:  WESTERN  ARABIAN PENINSULA                      1
# Name: Year, Length: 1697, dtype: int64

# %%
# Realizando agrupamentos de dados - qual o média de mortes para cada ano, relativa aos terremotos ocorridos
df_1990s_terremotos.groupby("Year")["Deaths"].mean()
# Out:
# Year
# 1900      82.500000
# 1901       8.666667
# 1902    1186.000000
# 1903    1105.333333
# 1904     138.000000
#            ...
# 1995     495.250000
# 1996      66.428571
# 1997     190.176471
# 1998     413.111111
# 1999     878.040000
# Name: Deaths, Length: 100, dtype: float64

# %%
# Calculando a média de mortes por terremotos na planilha selecionada
df_1990s_terremotos["Deaths"].mean()
# Out:
# 1623.9736575481256

# %%
# Calculando a soma de mortes por terremotos na planilha selecionada
df_1990s_terremotos["Deaths"].sum()
# Out:
# 1602862.0

# %%
# Calculando a soma de mortes por tsunamis na planilha selecionada
df_1990s_tsunamis["Deaths"].sum()
# Out:
# 48172.0

# %%
# Calculando a soma de mortes por vulcões na planilha selecionada
df_1990s_vulcoes["Deaths"].sum()
# Out:
# 81420.0

# %%
# Calculando a soma de mortes por terremotos na planilha selecionada
df_2000s_terremotos["Deaths"].sum()
# Out:
# 577777.0

# %%
# Calculando a soma de mortes por tsunamis na planilha selecionada
df_2000s_tsunamis["Deaths"].sum()
# Out:
# 252853.0

# %%
# Calculando a soma de mortes por terremotos na planilha selecionada * ainda incompleta
df_2000s_vulcoes["Deaths"].sum()
# Out:
# 2269.0

# %%
# Visualização de dados
# Quantas eventos existem em ordem do maior para o menor do referido ano na pesquisa
df_1990s_terremotos["Year"].value_counts(ascending=False)
# Out:
# 1990    51
# 1983    46
# 1991    42
# 1968    39
# 1961    35
#         ..
# 1940    16
# 1944    14
# 1908    13
# 1920    12
# 1945    12
# Name: Year, Length: 100, dtype: int64

# %%
# Visualização de dados
# Quantas eventos existem em ordem do maior para o menor do referido ano na pesquisa
df_2000s_terremotos["Year"].value_counts(ascending=False)
# Out:
# 2004    78
# 2008    77
# 2003    72
# 2018    69
# 2007    67
# 2017    64
# 2006    63
# 2010    62
# 2019    62
# 2009    61
# 2011    60
# 2002    60
# 2005    60
# 2014    55
# 2013    54
# 2016    52
# 2012    50
# 2015    48
# 2000    37
# 2021    36
# 2020    29
# 2001    26
# Name: Year, dtype: int64

# %%
# Filtrando uma variavel chamada país para apresentar todos os eventos referido ao mesmo na planilha selecionada.
Pais = df_2000s_vulcoes.loc[df_2000s_vulcoes["Country"] == "Italy"] 
Pais.head()
# Out:
#     Year    Mo  ...  Total Houses Destroyed  Total Houses Destroyed Description
# 5   2001   5.0  ...                     NaN                                 NaN
# 6   2001   7.0  ...                     NaN                                 1.0
# 8   2001  10.0  ...                     NaN                                 NaN
# 11  2002   8.0  ...                     NaN                                 2.0
# 13  2002  12.0  ...                     NaN                                 1.0
#
# [5 rows x 34 columns]

# %%
# Filtrando uma variavel chamada país para apresentar todos os eventos referido ao mesmo na planilha selecionada.
Pais = df_1990s_vulcoes.loc[df_1990s_vulcoes["Country"] == "Italy"] 
Pais.head()
# Out:
#     Year    Mo  ...  Total Houses Destroyed  Total Houses Destroyed Description
# 17  1905   3.0  ...                     NaN                                 NaN
# 19  1906   4.0  ...                     NaN                                 NaN
# 51  1916   7.0  ...                     NaN                                 NaN
# 61  1919   5.0  ...                    10.0                                 1.0
# 80  1928  11.0  ...                     NaN                                 NaN
#
# [5 rows x 34 columns]

# %%
# filtrando com a variavel o número de atividades vulcânicas por país.
df_1990s_vulcoes['Country'].value_counts(ascending=False).plot.bar()

# %%
# filtrando com a variavel o número de atividades vulcânicas por país. Dados em constante atualização
df_2000s_vulcoes['Country'].value_counts(ascending=False).plot.bar()

# %%
# filtrando com a variavel o número de atividades vulcânicas por país. Gráfico na horizontal
df_1990s_vulcoes['Country'].value_counts(ascending=True).plot.barh();

# %%
# filtrando com a variavel o número de atividades vulcânicas por país. Dados em constante atualização - gráfico na horizontal
df_2000s_vulcoes['Country'].value_counts(ascending=False).plot.barh()

# %%
# filtrando com a variavel o número de atividades vulcânicas por país. Dados em constante atualização
df_2000s_vulcoes['Country'].value_counts().plot.pie();

# %%
# Total de errupções vulcânicas por país no século XXI
df_2000s_vulcoes["Country"].value_counts()
# Out:
# Indonesia                       38
# United States                   12
# Papua New Guinea                11
# Italy                           10
# Japan                            9
# Ecuador                          8
# Philippines                      6
# New Zealand                      4
# Guatemala                        4
# Chile                            3
# Vanuatu                          3
# Colombia                         2
# Montserrat                       2
# Iceland                          2
# Congo, DRC                       2
# St. Vincent & the Grenadines     1
# Yemen                            1
# Eritrea                          1
# El Salvador                      1
# Russia                           1
# Peru                             1
# Spain                            1
# Cape Verde                       1
# Comoros                          1
# Costa Rica                       1
# Name: Country, dtype: int64

# %%
# Total de errupções vulcânicas por país no século XX
df_1990s_vulcoes["Country"].value_counts()
# Out:
# Indonesia                       86
# Japan                           84
# Philippines                     23
# Italy                           18
# Chile                           14
# United States                   12
# Guatemala                       11
# Papua New Guinea                11
# Russia                          11
# Iceland                          8
# Samoa                            8
# Mexico                           7
# Ecuador                          6
# Vanuatu                          6
# New Zealand                      5
# Colombia                         5
# Costa Rica                       5
# Tanzania                         4
# Congo, DRC                       4
# Martinique                       4
# Nicaragua                        4
# Comoros                          4
# Montserrat                       4
# Solomon Is.                      3
# Cameroon                         3
# El Salvador                      2
# St. Vincent & the Grenadines     2
# ...

# %%
# Total de registros de tsunamis por país no século XX
df_1990s_tsunamis["Country"].value_counts()
# Out:
# JAPAN            136
# USA              115
# INDONESIA         98
# CHILE             74
# RUSSIA            72
#                 ...
# ARGENTINA          1
# PACIFIC OCEAN      1
# UK TERRITORY       1
# GEORGIA            1
# SOUTH KOREA        1
# Name: Country, Length: 89, dtype: int64

# %%
# Total de registros de tsunamis por país no século XXI
df_2000s_tsunamis["Country"].value_counts()
# Out:
# JAPAN                            36
# INDONESIA                        32
# USA                              27
# NEW ZEALAND                      18
# SOLOMON ISLANDS                  15
# CHILE                            15
# VANUATU                          14
# NEW CALEDONIA                    13
# GREECE                           12
# PAPUA NEW GUINEA                 10
# RUSSIA                            9
# MEXICO                            7
# CANADA                            5
# CHINA                             5
# PHILIPPINES                       5
# SPAIN                             4
# PERU                              4
# SOUTH KOREA                       4
# TAIWAN                            4
# NORWAY                            3
# EL SALVADOR                       3
# USA TERRITORY                     3
# GREENLAND                         3
# ANTARCTICA                        3
# INDIA                             3
# ALGERIA                           3
# ...

# %%
* Colocando título no gráfico
df_2000s_tsunamis["Country"].value_counts().plot.bar(title="Total de tsunamis por país no século XXI")

# %%
# Colocando título no gráfico
df_2000s_tsunamis["Country"].value_counts().plot.barh(title="Total de tsunamis por país no século XX",color="red")
plt.xlabel("Country")
plt.ylabel("Deaths")
# Out:
# Text(0, 0.5, 'Deaths')

# %%
# Alterando o style
plt.style.use("ggplot")

# %%
# Colocando título no gráfico, e modificação no modelo do gráficodf_2000s_tsunamis.groupby(df_2000s_tsunamis['Year'])['Houses Destroyed'].sum().plot(title="Total de casas destruídas por ano")
plt.xlabel("Year")
plt.ylabel("Houses Destroyed")
plt.legend()

# %%
# determinando uma variavel para a quantidade de tsunamis no ano de 2006
df_2006 = df_2000s_tsunamis[df_2000s_tsunamis["Year"] == 2006]

# %%
# Grafico sobre o total de mortes no ano de 2006 dos países com asterisco em cada país
df_2006.groupby(df_2006['Country'])['Total Deaths'].sum().plot(title="Total de mortes nos países  no ano de 2006",marker="*")
plt.xlabel("Country")
plt.ylabel("Total Deaths")
plt.legend()

# %%
# Apresentação de todos os dados referente ao total de mortes no ano de 2006 para cada país atingidos por tsunamis.
df_2006.groupby(df_2006['Country'])['Total Deaths'].sum()
# Out:
# Country
# INDONESIA      806.0
# JAPAN            0.0
# MONTSERRAT       0.0
# RUSSIA           0.0
# SAMOA            0.0
# SOUTH KOREA      1.0
# SPAIN            0.0
# TAIWAN           2.0
# TONGA            0.0
# USA              0.0
# Name: Total Deaths, dtype: float64

# %%
# filtrando com a variavel o tipos de vulcões em atividade em execução no século XX. Dados em constante atualização
df_2000s_vulcoes['Type'].value_counts().plot.barh();
